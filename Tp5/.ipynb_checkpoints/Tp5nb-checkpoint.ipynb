# %% [markdown]
# # Trabajo práctico Nº5
#
# Transformación Euclideana. Es una transformación de **rotación** y **traslación**, una isometría que preserva la distancia y la orientación
#
#  $\begin{bmatrix}
#      x' \\
#      y' \\
#      1
#  \end{bmatrix} =
#  \begin{bmatrix}
#     \mathbf{R} & \mathbf{t}\\
#     \mathbf{0}^{T} & 1
#  \end{bmatrix}
# \begin{bmatrix}
#      x \\
#      y \\
#      1
#  \end{bmatrix}
#  $
#
# Donde:
#
# * **R** es la matriz 2x2 de **rotación**
#
# $\begin{bmatrix}
#     \cos(\theta) & \sin(\theta)\\
#    -\sin(\theta) & \cos(\theta)
#  \end{bmatrix}$
#
# * **t** es el vector de **traslación**:
#
# $\begin{bmatrix}
#     t_x\\
#     t_y
#  \end{bmatrix}$
#
# * El vector 0 y 1 se colocan para ajustar los tamaños para el producto matricial
#
# * En este caso la matriz $H_E$ tiene 3 grados de libertad, uno de la rotación y dos de la traslación
#
#
# 1.1) Creo una función que realice la transformación euclideana, que recibe como parámetros:
#
# * img: imagen a transformar
# * angle: ángulo de rotación
# * tx: traslación en x
# * ty: traslación en y

# %%
import cv2 
import matplotlib.pyplot as plt 
import numpy as np

def EuclideanTrans(img,angle,tx,ty): 
    (h,w) = img.shape[0], img.shape[1]
    #H  = np.float32([[np.cos(angle), np.sin(angle), tx], 
                  #-1*[np.sin(angle), np.cos(angle), ty]] )
    
    R = cv2.getRotationMatrix2D((w/2,h/2),angle,scale=1.0)
    H = np.float32([[R[0][0],R[0][1], tx], 
                    [R[1][0],R[1][1], ty]] )
    
    T = cv2.warpAffine(img,H,(w,h))
    return T

# %% [markdown]
# 1.2) Transformamos la imagen mediante la función

# %%
img =cv2.imread("./img/lena.jpeg")                                              
imgT = EuclideanTrans(img,30,20,20)

cv2.imshow("Imagen original",img)
cv2.imshow("Imagen transformada",img)
k = cv2.waitKey(0)
cv2.destroyAllWindows() 

plt.figure()
plt.subplot(1,2,1)
plt.title("Imagen original")
plt.imshow( cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.subplot(1,2,2)
plt.title("Imagen transformada")
plt.imshow( cv2.cvtColor(imgT, cv2.COLOR_BGR2RGB))

# %% [markdown]
# 2) Anexamos esta función al trabajo anterior:
#
# Con la letra “e” se aplica una transformación euclidiana a la porción de imagen
# seleccionada y se guarda como una nueva imagen.
#
# * Agregamos la función que atiene al evento de algun movimiento del mouse y algunas variables globales de control

# %%
drawing = False                                                                 
ix, iy = -1, -1                                                                 
fx, fy = -1, -1                                                                               
def draw (event,x,y,flags,param):                                               
    global ix, iy,fx,fy, drawing, mode                                          
    if event == cv2.EVENT_LBUTTONDOWN:                                          
        drawing = True                                                          
        ix, iy = x,y                                                            
    elif event == cv2.EVENT_MOUSEMOVE:                                          
        if drawing is True:                                                     
            imgSwap[:] = img[:]                                                 
            cv2.rectangle(imgSwap,(ix,iy), (x,y), (0,255,0),1)                  
    elif event == cv2.EVENT_LBUTTONUP:                                          
        drawing = False                                                         
        fx,fy = x,y                                                             
        cv2.rectangle(imgSwap,(ix,iy), (x,y), (0,255,0),1)

# %% [markdown]
# * Agregamos el menu desde donde se llaman al resto del funcioes

# %%
img =cv2.imread("./img/lena.jpeg")                                              
imgSwap =cv2.imread("./img/lena.jpeg")                                          
cv2.namedWindow("Ventana Imagen")                                               
cv2.setMouseCallback("Ventana Imagen",draw)                                     
                                                                                
print(" Opciones :" ,                                                           
            "g : Guardar porción de imagen",                                    
            "r : Limpiar la imagen",                                            
            "e : Transformar la seleccion ",                                    
            "q : salir " , sep = "\n" )                                         
while(1):                                                                       
    cv2.imshow("Ventana Imagen", imgSwap)                                       
    k = cv2.waitKey(1)                                                          
    if k == ord('q'):                                                           
        break                                                                   
    elif k == ord('g'):                                                         
        cv2.imwrite("./img/imagen_seleccionada.png",img[iy:fy, ix:fx])          
    elif k == ord('r'):                                                         
        imgSwap[:] = img[:]                                                     
    elif k == ord('e'):                                                         
        SelT = EuclideanTrans(img[ix:fx, iy:fy],10,20,20)                       
        cv2.imwrite("./img/sel_transformada.png",SelT)                          
                                                                                
cv2.destroyAllWindows()
# Out:
#  Opciones :
# g : Guardar porción de imagen
# r : Limpiar la imagen
# e : Transformar la seleccion
# q : salir
